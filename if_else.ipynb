# %% [markdown]
# <a href="https://colab.research.google.com/github/erbhishek12/Data-Science-Assignments/blob/Main/if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#program - Find the sum of a 3 digit number entered by the user

number = int(input('Enter a 3 digit number'))

a = number%10 #345%10--> 5

number = number//10 #345//10-->34 # number=34

b = number%10 # 34%10 :b=4

c = number//10 #34//10 :number=3

print(a+b+c)
# Out:
# Enter a 3 digit number345
# 12

# %% [markdown]
# # If-Else in Python

# %%
# login program and indentation
# email -> abhi.am991@gmail.com
# password -> 12345

email = input('Enter your emai:')
password = input('Enter the password')

if email == 'abhi.am991@gmail.com' and password == '12345':
  print('welcome')
elif email == 'abhi.am991@gmail.com' and password != '12345':
  print('incorrect password')
  password = input('enter password again')
  if password == '12345':
    print('welcome,finally!')
  else:
    print('beta tmse na ho payega!')
else:
  print('not correct')
# Out:
# Enter your emai:wertyui
# Enter the password12345
# not correct

# %%
#finding min of 3 numbers
a = int(input('Enter the first number'))
b = int(input('Enter the second number'))
c = int(input('Enter the third7 number'))

if a<b and a<c:
  print('smallest is', a)
elif b<c:
  print ('smallest is', b)
else:
   print ('smallest is', c)
# Out:
# Enter the first number4
# Enter the second number4
# Enter the third7 number4
# smallest is 4

# %%
#finding min of 4 numbers
a = int(input('Enter the first number'))
b = int(input('Enter the second number'))
c = int(input('Enter the third number'))
d = int(input('Enter the fourth number'))

if a<b and a<c and a<d:
  print('smallest is', a)
elif b<c and b<d:
  print ('smallest is', b)
elif c<d:
  print ('smallest is', c)
else:
   print ('smallest is', d)
# Out:
# Enter the first number9
# Enter the second number0
# Enter the third number8
# Enter the fourth number7
# smallest is 0

# %%
#menu driven calc
fnum = int(input('Enter the first number'))
snum = int(input('Enter the second number'))
op = input('Enter the operation')

if op == '+':
  print(fnum + snum)
elif op == '-':
  print(fnum - snum)
elif op == '*':
  print(fnum*snum)
else:
  print(fnum/snum)
# Out:
# Enter the first number6
# Enter the second number7
# Enter the operation-
# -1

# %%
#menu driven ATM
menu= input("""
Hi! how can i help you.
1. Enter 1 for pin change
2. Enter 2 for balance enquiry
3. Enter 3 for cash withdrawl
4. Enter 4 for exit""")

if menu == '1':
  print('pin change')
elif menu == '2':
  print('balance enquiry')
elif menu == '3':
  print('cash withdrawl')
else:
  print('exit')
# Out:
# Hi! how can i help you.
# 1. Enter 1 for pin change
# 2. Enter 2 for balance enquiry
# 3. Enter 3 for cash withdrawl
# 4. Enter 4 for exit3
# cash withdrawl
